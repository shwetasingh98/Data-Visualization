# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Bondora_Preprocessed.csv")
df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7616\3079219385.py:1: DtypeWarning: Columns (16,17,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Bondora_Preprocessed.csv")
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0                     0        0    115.0410               True
# 1                     0        0    140.6057              False
# 2                     0        0    319.5580               True
# 3                     0        0     57.5205               True
# 4                     0        0    319.5582               True
#
#    VerificationType  LanguageCode  Age  Gender Country  AppliedAmount  ...  \
# 0               2.0             1   61     1.0      EE       319.5582  ...
# 1               2.0             1   48     1.0      EE       191.7349  ...
# 2               2.0             1   58     1.0      EE       319.5582  ...
# ...

# %%
df.shape
# Out:
# (134529, 43)

# %%
df.describe()
# Out:
#        BidsPortfolioManager        BidsApi     BidsManual  VerificationType  \
# count         134529.000000  134529.000000  134529.000000     134484.000000
# mean             966.452876      29.111664     559.332590          2.817257
# std             1355.686016     150.159148     750.360512          1.407908
# min                0.000000       0.000000       0.000000          0.000000
# 25%              155.000000       0.000000      96.000000          1.000000
# 50%              465.000000       0.000000     317.000000          4.000000
# 75%             1218.000000       5.000000     729.000000          4.000000
# max            10625.000000    7570.000000   10630.000000          4.000000
#
#         LanguageCode            Age         Gender  AppliedAmount  \
# count  134529.000000  134529.000000  134484.000000  134529.000000
# mean        2.827874      40.819295       0.442097    2727.947540
# std         1.959802      12.348693       0.636083    2374.439168
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
def catog(lst):
    for i in lst:
        df[i]=df[i].astype("category")

# %%
lst=['Target','CreditScoreEsMicroL','Rating','Country','UseOfLoan','Education','MaritalStatus','EmploymentStatus',
    'EmploymentDurationCurrentEmployer','OccupationArea','HomeOwnershipType','LanguageCode','VerificationType','Gender']
catog(lst)

# %% [markdown]
# # Univariate analysis

# %%
df['MaritalStatus'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=df, x="Country")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
df['Rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Country'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df['NewCreditCustomer'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['HomeOwnershipType'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 5))
df['Target'].value_counts().plot(kind='pie',autopct='%.2f%%',labels=['Default','not-default'],wedgeprops={'edgecolor':'green'})
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f%%',wedgeprops={'edgecolor':'black'},labels=['Male','Female','Not_specified'])
plt.show()

# %%
sns.boxplot(df['BidsManual'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BidsManual'>

# %%
plt.hist(df['Age'])
# Out:
# (array([   53.,     0.,  8403., 23523., 31479., 27784., 19283., 15098.,
#          8235.,   671.]),
#  array([ 0. ,  7.7, 15.4, 23.1, 30.8, 38.5, 46.2, 53.9, 61.6, 69.3, 77. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Bivariate Analysis

# %%
sns.barplot(data=df,x='EmploymentStatus',y='NoOfPreviousLoansBeforeLoan',hue="Target")
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='NoOfPreviousLoansBeforeLoan'>

# %%
sns.scatterplot(df.index,df["Country"],hue=df["Rating"])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Country'>

# %%
sns.barplot(data=df,x='Country',y='NoOfPreviousLoansBeforeLoan',hue="Target")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='NoOfPreviousLoansBeforeLoan'>

# %% [markdown]
# # Multivariate Analysis

# %%
rat_model=df[['ExistingLiabilities','LiabilitiesTotal' ,'RefinanceLiabilities','Rating','HomeOwnershipType','Age','City','MaritalStatus','IncomeTotal']]

# %%
rat_model
# Out:
#         ExistingLiabilities  LiabilitiesTotal  RefinanceLiabilities Rating  \
# 0                         0              0.00                     0    NaN
# 1                         0              0.00                     0    NaN
# 2                         0              0.00                     0    NaN
# 3                         0              0.00                     0    NaN
# 4                         0              0.00                     0    NaN
# ...                     ...               ...                   ...    ...
# 134524                    1            500.00                     0      E
# 134525                    5           1777.46                     0      B
# 134526                    2           1350.00                     0      D
# 134527                    8            732.05                     2      B
# 134528                    5            531.03                     1      D
#
# ...

# %%
sns.heatmap(rat_model.corr(), cmap="YlGnBu", annot=True);

# %%
df2=df[["Country","AppliedAmount","LoanDuration","Interest","OccupationArea","Rating","MaritalStatus",'IncomeTotal']]
df2.head()
# Out:
#   Country  AppliedAmount  LoanDuration  Interest OccupationArea Rating  \
# 0      EE       319.5582            12      30.0            7.0    NaN
# 1      EE       191.7349             1      25.0           16.0    NaN
# 2      EE       319.5582            20      25.0            9.0    NaN
# 3      EE       127.8233            15      45.0            1.0    NaN
# 4      EE       319.5582            12      30.0            7.0    NaN
#
#   MaritalStatus  IncomeTotal
# 0           1.0      10500.0
# 1           4.0      10800.0
# 2           1.0       7000.0
# 3           3.0      11600.0
# 4           2.0       6800.0

# %%
sns.pairplot(df2,hue= "Country",size=10)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df3=df[["AppliedAmount","Amount","MaritalStatus","IncomeTotal"]]
sns.pairplot(df3,hue= "MaritalStatus",size=10)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
